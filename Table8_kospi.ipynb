# %%
import pandas as pd
import numpy as np
from Fin import *
from Stat import *
from scipy import stats
import statsmodels.api as sm
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 필요한 데이터 먼저 테이블로 정렬시키기

# %%
Alldata = pd.read_excel("Data/kospi/Alldata.xlsx")
UseOnlyPort = Alldata[['Symbol','회계년','Name','시가총액','consen_cut','CompuConsen','valPEIS','deltaprice','PER',\
                      'PBR', 'BETA']]
UseOnlyPort['ACC'] = Alldata['영업이익(천원)'] - Alldata['영업활동으로인한현금흐름(천원)']
UseOnlyPort['HEDGE'] = 0

# %% [markdown]
# #  포트폴리오 구성하기
# 1. 컨센별 포트폴리오 ConsenPorts
# 2. PEIS별 포트폴리오 PEISPorts
# 3. Uncondi Hold Table8list
# 4. condi Hold 마지막 라인~
# * 여기서는 Strongbuy/ buy만 쓰면댐 / sell이 없어서 걍 홀드를 sell로 보자

# %%
ConsenPorts = MakePortbyCriteria(UseOnlyPort, 'consen_cut')
PEISPorts = MakePortbyPEIS(UseOnlyPort)
for i in ConsenPorts:
    i.ConsenPEIS()
    i.Maketable8() 
# 다중회귀 더 하는 것
Table8list = [PEISPorts[0],PEISPorts[4],ConsenPorts[2]]
Maketable8(Table8list)
ConsenPorts[2].PEIS[0].Maketable8()
ConsenPorts[2].PEIS[4].Maketable8()

ConsenPorts[0].PEIS[0].Maketable8()
ConsenPorts[0].PEIS[4].Maketable8()

# %% [markdown]
# # BUY / SELL 전략

# %%
MultiLinear(ConsenPorts[3].table8,ConsenPorts[2].table8)
# Out:
# N :  2170
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.067
# Model:                            OLS   Adj. R-squared:                  0.065
# Method:                 Least Squares   F-statistic:                     26.00
# Date:                Sat, 22 May 2021   Prob (F-statistic):           5.34e-30
# Time:                        22:27:56   Log-Likelihood:                -1423.4
# No. Observations:                2170   AIC:                             2861.
# Df Residuals:                    2163   BIC:                             2900.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1763      0.050     -3.500      0.000      -0.275      -0.078
# HEDGE          0.1835      0.046      4.019      0.000       0.094       0.273
# PBR           -0.0039      0.003     -1.139      0.255      -0.011       0.003
# RET            0.2298      0.020     11.635      0.000       0.191       0.269
# PER        -6.952e-05      0.000     -0.602      0.547      -0.000       0.000
# ACC        -1.503e-11   6.41e-12     -2.344      0.019   -2.76e-11   -2.46e-12
# BETA           0.0182      0.024      0.770      0.441      -0.028       0.065
# ==============================================================================
# Omnibus:                      884.299   Durbin-Watson:                   2.048
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            19205.603
# Skew:                           1.396   Prob(JB):                         0.00
# Kurtosis:                      17.305   Cond. No.                     1.04e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # fundamental 전략

# %%
MultiLinear(PEISPorts[4].table8, PEISPorts[0].table8)
# Out:
# N :  2459
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.055
# Model:                            OLS   Adj. R-squared:                  0.053
# Method:                 Least Squares   F-statistic:                     23.92
# Date:                Sat, 22 May 2021   Prob (F-statistic):           1.23e-27
# Time:                        22:27:56   Log-Likelihood:                -2068.3
# No. Observations:                2459   AIC:                             4151.
# Df Residuals:                    2452   BIC:                             4191.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1167      0.031     -3.825      0.000      -0.177      -0.057
# HEDGE          0.1916      0.027      7.170      0.000       0.139       0.244
# PBR           -0.0025      0.001     -2.123      0.034      -0.005      -0.000
# RET            0.1576      0.019      8.358      0.000       0.121       0.195
# PER           -0.0001   9.74e-05     -1.068      0.286      -0.000     8.7e-05
# ACC         6.931e-12   1.37e-11      0.506      0.613   -1.99e-11    3.38e-11
# BETA           0.0601      0.025      2.363      0.018       0.010       0.110
# ==============================================================================
# Omnibus:                     1080.914   Durbin-Watson:                   2.016
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            13851.076
# Skew:                           1.726   Prob(JB):                         0.00
# Kurtosis:                      14.102   Cond. No.                     2.88e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Unconditional Hold 전략

# %%
MultiLinear(ConsenPorts[2].table8)
# Out:
# N :  111
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     2.397
# Date:                Sat, 22 May 2021   Prob (F-statistic):             0.0422
# Time:                        22:27:56   Log-Likelihood:                -103.85
# No. Observations:                 111   AIC:                             219.7
# Df Residuals:                     105   BIC:                             235.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.2166      0.162     -1.338      0.184      -0.537       0.104
# PBR            0.1213      0.042      2.916      0.004       0.039       0.204
# RET           -0.1747      0.089     -1.953      0.053      -0.352       0.003
# PER           -0.0002      0.001     -0.183      0.855      -0.002       0.002
# ACC        -2.472e-11   9.43e-11     -0.262      0.794   -2.12e-10    1.62e-10
# BETA          -0.0444      0.144     -0.308      0.759      -0.331       0.242
# ==============================================================================
# Omnibus:                      121.480   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2382.753
# Skew:                          -3.679   Prob(JB):                         0.00
# Kurtosis:                      24.472   Cond. No.                     2.24e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.24e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # conditional Hold 전략

# %%
MultiLinear(ConsenPorts[2].PEIS[4].table8, ConsenPorts[2].PEIS[0].table8)
# Out:
# N :  25
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.261
# Model:                            OLS   Adj. R-squared:                  0.014
# Method:                 Least Squares   F-statistic:                     1.057
# Date:                Sat, 22 May 2021   Prob (F-statistic):              0.423
# Time:                        22:27:56   Log-Likelihood:                -13.103
# No. Observations:                  25   AIC:                             40.21
# Df Residuals:                      18   BIC:                             48.74
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.4242      0.314      1.350      0.194      -0.236       1.084
# HEDGE         -0.2676      0.248     -1.081      0.294      -0.788       0.252
# PBR           -0.0669      0.044     -1.514      0.147      -0.160       0.026
# RET           -0.1173      0.321     -0.365      0.719      -0.792       0.558
# PER            0.0021      0.002      0.962      0.349      -0.002       0.007
# ACC         1.122e-10   1.14e-10      0.985      0.338   -1.27e-10    3.51e-10
# BETA          -0.1784      0.227     -0.785      0.443      -0.656       0.299
# ==============================================================================
# Omnibus:                        0.001   Durbin-Watson:                   1.865
# Prob(Omnibus):                  0.999   Jarque-Bera (JB):                0.169
# Skew:                          -0.002   Prob(JB):                        0.919
# Kurtosis:                       2.597   Cond. No.                     3.91e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.91e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
MultiLinear(ConsenPorts[0].table8)
# Out:
# N :  3879
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.038
# Model:                            OLS   Adj. R-squared:                  0.037
# Method:                 Least Squares   F-statistic:                     30.90
# Date:                Sat, 22 May 2021   Prob (F-statistic):           6.21e-31
# Time:                        23:11:17   Log-Likelihood:                -4018.6
# No. Observations:                3879   AIC:                             8049.
# Df Residuals:                    3873   BIC:                             8087.
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0808      0.021      3.761      0.000       0.039       0.123
# PBR           -0.0048      0.001     -3.467      0.001      -0.007      -0.002
# RET            0.1860      0.016     11.676      0.000       0.155       0.217
# PER         1.874e-06   1.68e-05      0.111      0.911   -3.11e-05    3.49e-05
# ACC        -2.037e-11   6.34e-11     -0.322      0.748   -1.45e-10    1.04e-10
# BETA           0.0444      0.025      1.773      0.076      -0.005       0.094
# ==============================================================================
# Omnibus:                     4304.766   Durbin-Watson:                   2.099
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):           783110.453
# Skew:                           5.350   Prob(JB):                         0.00
# Kurtosis:                      71.780   Cond. No.                     5.01e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 5.01e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %%
MultiLinear(ConsenPorts[0].PEIS[4].table8, ConsenPorts[0].PEIS[0].table8)
# Out:
# N :  1526
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.064
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     17.21
# Date:                Sat, 22 May 2021   Prob (F-statistic):           2.49e-19
# Time:                        23:11:24   Log-Likelihood:                -1448.5
# No. Observations:                1526   AIC:                             2911.
# Df Residuals:                    1519   BIC:                             2948.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const         -0.1621      0.046     -3.534      0.000      -0.252      -0.072
# HEDGE          0.2730      0.043      6.405      0.000       0.189       0.357
# PBR           -0.0026      0.001     -1.879      0.060      -0.005       0.000
# RET            0.1658      0.025      6.670      0.000       0.117       0.215
# PER        -8.289e-05      0.000     -0.640      0.522      -0.000       0.000
# ACC         1.201e-10   1.66e-10      0.722      0.470   -2.06e-10    4.46e-10
# BETA           0.0765      0.035      2.188      0.029       0.008       0.145
# ==============================================================================
# Omnibus:                      679.040   Durbin-Watson:                   1.996
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             6790.267
# Skew:                           1.810   Prob(JB):                         0.00
# Kurtosis:                      12.679   Cond. No.                     3.64e+08
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.64e+08. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
