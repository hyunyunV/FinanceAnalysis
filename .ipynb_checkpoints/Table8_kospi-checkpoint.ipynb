# %%
import pandas as pd
import numpy as np
from Fin import *
from Stat import *
from scipy import stats
import statsmodels.api as sm
import warnings

warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 필요한 데이터 먼저 테이블로 정렬시키기

# %%
Alldata = pd.read_excel("Data/kospi/Alldata.xlsx")
UseOnlyPort = Alldata[['Symbol','회계년','Name','시가총액','consen_cut','CompuConsen','valPEIS','deltaprice','PER',\
                      'PBR', 'BETA']]
UseOnlyPort['ACC'] = Alldata['영업이익(천원)'] - Alldata['영업활동으로인한현금흐름(천원)']
UseOnlyPort['HEDGE'] = 0

# %% [markdown]
# #  포트폴리오 구성하기
# 1. 컨센별 포트폴리오 ConsenPorts
# 2. PEIS별 포트폴리오 PEISPorts
# 3. Uncondi Hold Table8list
# 4. condi Hold 마지막 라인~
# * 여기서는 Strongbuy/ buy만 쓰면댐 / sell이 없어서 걍 홀드를 sell로 보자

# %%
ConsenPorts = MakePortbyCriteria(UseOnlyPort, 'consen_cut')
PEISPorts = MakePortbyPEIS(UseOnlyPort)
for i in ConsenPorts:
    i.ConsenPEIS()
    i.Maketable8() 
# 다중회귀 더 하는 것
Table8list = [PEISPorts[0],PEISPorts[4],ConsenPorts[2]]
Maketable8(Table8list)
ConsenPorts[2].PEIS[0].Maketable8()
ConsenPorts[2].PEIS[4].Maketable8()

# %% [markdown]
# # BUY / SELL 전략

# %%
MultiLinear(ConsenPorts[3].table8,ConsenPorts[2].table8)
# Out:
# N :  2170
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.082
# Model:                            OLS   Adj. R-squared:                  0.079
# Method:                 Least Squares   F-statistic:                     32.12
# Date:                Fri, 21 May 2021   Prob (F-statistic):           3.30e-37
# Time:                        10:52:07   Log-Likelihood:                -1403.3
# No. Observations:                2170   AIC:                             2821.
# Df Residuals:                    2163   BIC:                             2860.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0731      0.050      1.466      0.143      -0.025       0.171
# HEDGE         -0.0643      0.045     -1.421      0.155      -0.153       0.024
# PBR           -0.0068      0.003     -2.001      0.046      -0.013      -0.000
# RET            0.2592      0.020     13.242      0.000       0.221       0.298
# PER        -4.062e-05      0.000     -0.355      0.723      -0.000       0.000
# ACC        -1.488e-11   6.35e-12     -2.342      0.019   -2.73e-11   -2.42e-12
# BETA           0.0195      0.023      0.831      0.406      -0.027       0.066
# ==============================================================================
# Omnibus:                     1266.951   Durbin-Watson:                   2.039
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            17342.782
# Skew:                           2.490   Prob(JB):                         0.00
# Kurtosis:                      15.923   Cond. No.                     1.04e+10
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 1.04e+10. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # fundamental 전략

# %%
MultiLinear(PEISPorts[4].table8, PEISPorts[0].table8)
# Out:
# N :  2459
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.077
# Model:                            OLS   Adj. R-squared:                  0.075
# Method:                 Least Squares   F-statistic:                     34.13
# Date:                Fri, 21 May 2021   Prob (F-statistic):           9.06e-40
# Time:                        10:52:19   Log-Likelihood:                -2015.1
# No. Observations:                2459   AIC:                             4044.
# Df Residuals:                    2452   BIC:                             4085.
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.0016      0.030      0.053      0.958      -0.057       0.060
# HEDGE          0.0515      0.026      1.970      0.049       0.000       0.103
# PBR           -0.0030      0.001     -2.585      0.010      -0.005      -0.001
# RET            0.2433      0.018     13.186      0.000       0.207       0.280
# PER           -0.0001   9.53e-05     -1.320      0.187      -0.000    6.11e-05
# ACC        -8.063e-12   1.34e-11     -0.602      0.548   -3.43e-11    1.82e-11
# BETA           0.0714      0.025      2.866      0.004       0.023       0.120
# ==============================================================================
# Omnibus:                     1367.997   Durbin-Watson:                   2.014
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):            16348.471
# Skew:                           2.390   Prob(JB):                         0.00
# Kurtosis:                      14.693   Cond. No.                     2.88e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.88e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # Unconditional Hold 전략

# %%
MultiLinear(ConsenPorts[2].table8)
# Out:
# N :  111
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.102
# Model:                            OLS   Adj. R-squared:                  0.060
# Method:                 Least Squares   F-statistic:                     2.397
# Date:                Fri, 21 May 2021   Prob (F-statistic):             0.0422
# Time:                        10:55:17   Log-Likelihood:                -103.85
# No. Observations:                 111   AIC:                             219.7
# Df Residuals:                     105   BIC:                             235.9
# Df Model:                           5
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.2166      0.162      1.338      0.184      -0.104       0.537
# PBR           -0.1213      0.042     -2.916      0.004      -0.204      -0.039
# RET            0.1747      0.089      1.953      0.053      -0.003       0.352
# PER            0.0002      0.001      0.183      0.855      -0.002       0.002
# ACC         2.472e-11   9.43e-11      0.262      0.794   -1.62e-10    2.12e-10
# BETA           0.0444      0.144      0.308      0.759      -0.242       0.331
# ==============================================================================
# Omnibus:                      121.480   Durbin-Watson:                   2.088
# Prob(Omnibus):                  0.000   Jarque-Bera (JB):             2382.753
# Skew:                           3.679   Prob(JB):                         0.00
# Kurtosis:                      24.472   Cond. No.                     2.24e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 2.24e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """

# %% [markdown]
# # conditional Hold 전략

# %%
MultiLinear(ConsenPorts[2].PEIS[4].table8, ConsenPorts[2].PEIS[0].table8)
# Out:
# N :  25
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ==============================================================================
# Dep. Variable:                     AR   R-squared:                       0.346
# Model:                            OLS   Adj. R-squared:                  0.127
# Method:                 Least Squares   F-statistic:                     1.585
# Date:                Fri, 21 May 2021   Prob (F-statistic):              0.209
# Time:                        10:51:43   Log-Likelihood:                -10.740
# No. Observations:                  25   AIC:                             35.48
# Df Residuals:                      18   BIC:                             44.01
# Df Model:                           6
# Covariance Type:            nonrobust
# ==============================================================================
#                  coef    std err          t      P>|t|      [0.025      0.975]
# ------------------------------------------------------------------------------
# const          0.3113      0.286      1.089      0.290      -0.289       0.912
# HEDGE          0.1222      0.225      0.542      0.594      -0.351       0.595
# PBR           -0.0711      0.040     -1.767      0.094      -0.156       0.013
# RET           -0.1463      0.292     -0.500      0.623      -0.761       0.468
# PER            0.0026      0.002      1.311      0.206      -0.002       0.007
# ACC         1.506e-10   1.04e-10      1.454      0.163    -6.7e-11    3.68e-10
# BETA          -0.4695      0.207     -2.269      0.036      -0.904      -0.035
# ==============================================================================
# Omnibus:                        0.995   Durbin-Watson:                   1.180
# Prob(Omnibus):                  0.608   Jarque-Bera (JB):                0.459
# Skew:                           0.331   Prob(JB):                        0.795
# Kurtosis:                       3.035   Cond. No.                     3.91e+09
# ==============================================================================
#
# Warnings:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly specified.
# [2] The condition number is large, 3.91e+09. This might indicate that there are
# strong multicollinearity or other numerical problems.
# """
