# %% [markdown]
# # 포트폴리오 구성에사용되는 항목만 인덱싱
# 0. 인덱스 때기
# 1. 시가총액 (AR)
# 2. 투자시 수익률 (deltaprofit)
# 3. PEIS 점수들 --> 이거는 따로 빼주는 게 좋을 것 같기도
# 4. 컨센의견
#
# ---------
# * 코스닥 코스피 기간 수익률도 가져오기

# %% [markdown]
# # 코스피

# %% [markdown]
# # Table7_1

# %%
import pandas as pd
import numpy as np
from Fin import *
from Stat import *
from scipy import stats
import warnings

warnings.filterwarnings(action='ignore')

# %%
Alldata = pd.read_excel("Data/kospi/Alldata.xlsx")
UseOnlyPort = Alldata[['회계년','Name','시가총액','consen_cut','CompuConsen','valPEIS','deltaprice']]

# %% [markdown]
# # 컨센안에서 PEIS별 포트폴리오

# %%
ConsenPorts = MakePortbyCriteria(UseOnlyPort, 'consen_cut')
for i in ConsenPorts:
    i.ConsenPEIS()

# %% [markdown]
# # Consen전체랑 Consen groupby PEIS

# %%
AllDataby_consen = AllTable7(ConsenPorts)
ConsenPEIS_table = ConsenPEISTable7(ConsenPorts)

# %%
FinalForm = pd.concat([AllDataby_consen, ConsenPEIS_table], axis=1)
FinalForm.columns = ['ALL','PEIS1','PEIS2','PEIS3','PEIS4','PEIS5']
FinalForm['PEIS 5 - 1'] = FinalForm['PEIS5'] - FinalForm['PEIS1']
FinalForm = FinalForm.round(4)
FinalForm.iloc[[0,1,3,4,6,7,9,10,12,13],6] = ' '
FinalForm
# Out:
#               ALL     PEIS1     PEIS2    PEIS3      PEIS4      PEIS5  \
# 0 N       4511.00  767.0000  913.0000   0.0000  1120.0000  1711.0000
#   CR (%)     0.14    0.1461    0.1223   0.0000     0.1417     0.1400
#   AR (%)     0.10    0.1291    0.0496   0.0000     0.0748     0.1495
# 1 N          2.00    1.0000    0.0000   0.0000     0.0000     1.0000
#   CR (%)    -0.33   -0.2882    0.0000   0.0000     0.0000    -0.3719
#   AR (%)     0.00    0.0000    0.0000   0.0000     0.0000     0.0000
# 2 N        254.00   45.0000    0.0000  68.0000    69.0000    72.0000
#   CR (%)     0.05   -0.0588    0.0000  -0.0002     0.1743     0.0179
#   AR (%)     0.11    0.1246    0.0000   0.0735     0.2113    -0.0866
# 3 N       2544.00  411.0000  566.0000   0.0000   666.0000   901.0000
#   CR (%)     0.06    0.0620    0.0663   0.0000     0.0449     0.0806
#   AR (%)     0.01    0.0065    0.0434   0.0000    -0.0328     0.0095
# 4 N         11.00    1.0000    3.0000   2.0000     0.0000     5.0000
#   CR (%)    -0.24    0.0571   -0.1216  -0.1809     0.0000    -0.2576
#   AR (%)     0.00    0.0000    0.0000   0.0000     0.0000     0.0000
#
#          PEIS 5 - 1
# 0 N
#   CR (%)
#   AR (%)     0.0204
# 1 N
#   CR (%)
#   AR (%)        0.0
# 2 N
#   CR (%)
#   AR (%)    -0.2112
# 3 N
#   CR (%)
#   AR (%)      0.003
# 4 N
#   CR (%)
#   AR (%)        0.0

# %%
ttest([0,2,3], ConsenPorts)
# Out:
# statistic : 0 , pvalue : 0.8240860
#
#
# statistic : 1 , pvalue : 0.3117403
#
#
# statistic : 0 , pvalue : 0.9705054

# %%
FinalForm.iloc[11,6] = str(round(FinalForm.iloc[11,6],4)) + '** '
FinalForm.index = [ ['No consen']*3+['Sell']*3+['Hold']*3+['Buy']*3+['S_Buy']*3, ['N', 'CR (%)', 'AR (%)']*5]

# %%
FinalForm.to_excel('Data/kospi/table7_1.xlsx')
FinalForm
# Out:
#                       ALL     PEIS1     PEIS2    PEIS3      PEIS4      PEIS5  \
# No consen N       4511.00  767.0000  913.0000   0.0000  1120.0000  1711.0000
#           CR (%)     0.14    0.1461    0.1223   0.0000     0.1417     0.1400
#           AR (%)     0.10    0.1291    0.0496   0.0000     0.0748     0.1495
# Sell      N          2.00    1.0000    0.0000   0.0000     0.0000     1.0000
#           CR (%)    -0.33   -0.2882    0.0000   0.0000     0.0000    -0.3719
#           AR (%)     0.00    0.0000    0.0000   0.0000     0.0000     0.0000
# Hold      N        254.00   45.0000    0.0000  68.0000    69.0000    72.0000
#           CR (%)     0.05   -0.0588    0.0000  -0.0002     0.1743     0.0179
#           AR (%)     0.11    0.1246    0.0000   0.0735     0.2113    -0.0866
# Buy       N       2544.00  411.0000  566.0000   0.0000   666.0000   901.0000
#           CR (%)     0.06    0.0620    0.0663   0.0000     0.0449     0.0806
#           AR (%)     0.01    0.0065    0.0434   0.0000    -0.0328     0.0095
# S_Buy     N         11.00    1.0000    3.0000   2.0000     0.0000     5.0000
#           CR (%)    -0.24    0.0571   -0.1216  -0.1809     0.0000    -0.2576
#           AR (%)     0.00    0.0000    0.0000   0.0000     0.0000     0.0000
#
#                  PEIS 5 - 1
# No consen N
#           CR (%)
#           AR (%)     0.0204
# Sell      N
#           CR (%)
#           AR (%)        0.0
# Hold      N
#           CR (%)
#           AR (%)    -0.2112
# Buy       N
#           CR (%)
#           AR (%)   0.003**
# S_Buy     N
#           CR (%)
#           AR (%)        0.0

# %% [markdown]
# # Table7_2

# %% [markdown]
# # PEIS별 포트폴리오_quantile 20씩 끊음 & 컨센별 포트폴리오

# %%
PEISPorts = MakePortbyPEIS(UseOnlyPort)
ConsenPorts = MakePortbyCriteria(UseOnlyPort, 'consen_cut')

# %% [markdown]
# # 노가다로 끼워맞춤.. 귀찮으니깐 마지막에..

# %%
x, y = ConsenPorts[3].ARreturnlist,ConsenPorts[2].ARreturnlist
_stat,_pvalue = stats.levene(x,y)
print("LeveneResult -- stat : %3f, p-value : %3f \n" %(_stat, _pvalue))
if _pvalue < 0.05:
    equal_Var = False
else :
    equal_Var = True
print(equal_Var)
statistic , pvalue = stats.ttest_ind(x,y, equal_var= equal_Var)
print("\nstatistic : %d , pvalue : %.7f\n" % (statistic, pvalue))
# Out:
# LeveneResult -- stat : 0.374743, p-value : 0.548086
#
# True
#
# statistic : -1 , pvalue : 0.2938548

# %%
ConsenPorts[3].AR
# Out:
# 0.010481123018958392

# %%
ConsenPorts[1].AR
# Out:
# 0.0
